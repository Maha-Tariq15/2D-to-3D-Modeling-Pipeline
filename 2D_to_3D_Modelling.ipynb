# %%
# !git clone https://github.com/VAST-AI-Research/TripoSG.git
# %cd TripoSG
# Out:
# Cloning into 'TripoSG'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 167 (delta 64), reused 49 (delta 49), pack-reused 75 (from 1)
# Receiving objects: 100% (167/167), 15.66 MiB | 16.79 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# /content/TripoSG

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/TripoSG
# Out:
# /content/TripoSG

# %%
# !git log --oneline | head
# Out:
# fc5c409 Update README.md
# beb1903 Merge pull request #28 from DrCyanide/main
# ef458aa Merge branch 'main' into main
# 44ed102 Add support for TripoSG-scribble model. (#33)
# 913a75d Update README.md
# 0843254 Added face limits and output name args
# 22a2a65 Merge pull request #25 from xczz1118/triposg-flashvdm
# d3a6e76 fix scale bug
# 01c9484 Merge pull request #23 from xczz1118/triposg-flashvdm
# 96a6dd8 update flashvdm

# %%
# !git log --oneline
# Out:
# fc5c409 (HEAD -> main, origin/main, origin/HEAD) Update README.md
# beb1903 Merge pull request #28 from DrCyanide/main
# ef458aa Merge branch 'main' into main
# 44ed102 Add support for TripoSG-scribble model. (#33)
# 913a75d Update README.md
# 0843254 Added face limits and output name args
# 22a2a65 Merge pull request #25 from xczz1118/triposg-flashvdm
# d3a6e76 fix scale bug
# 01c9484 Merge pull request #23 from xczz1118/triposg-flashvdm
# 96a6dd8 update flashvdm
# 2039b46 update license notice
# 8acb817 use flashvdm
# ca7ffd3 add diso
# 843cf0e full vae reconstruction
# 1f9bd47 full vae reconstruction
# e84ec38 Update README.md
# 3f2d11d update README.md
# 88cfe71 delete torch-cluster
# b52f852 update requirments.txt
# 39ff076 minor fixes for running on windows
# 67a41e0 Merge pull request #2 from BinaryCheater/main
# e59aca0 Update inference_triposg.py, fix repo name
# 517c3d9 Initial release

# %%
# !git checkout 843cf0e
# Out:
# Note: switching to '843cf0e'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 843cf0e full vae reconstruction

# %%
# !pip install diffusers transformers einops huggingface_hub opencv-python trimesh omegaconf scikit-image
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.0/737.0 kB 22.6 MB/s eta 0:00:00
# ...

# %%
# !pip install jaxtyping

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14889078-be37-4b08-8d27-843c5b669b41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14889078-be37-4b08-8d27-843c5b669b41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p output

# %%
# !python -m scripts.inference_triposg \
    --image-input WOLF.jpg \
    --output-dir output
# Out:
# 2025-12-12 06:19:25.042588: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765520365.059205     590 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765520365.064118     590 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765520365.076787     590 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls -lh output
# Out:
# total 0

# %%
from google.colab import files
files.download("output/output.glb")

# %%
import torch
torch.cuda.empty_cache()
torch.cuda.ipc_collect()
